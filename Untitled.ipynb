# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
columns = ["Point", "pt1" , "pt2"]
df1 = pd.read_csv("geoPoints0.csv", header=None, names=columns)
df2 = pd.read_csv("geoPoints1.csv", header=None, names=columns)

# %%
x = pd.concat([df1, df2])

# %%
ax1 = x.plot.scatter(x='pt1',
...                       y='pt2',
...                       c='DarkBlue',grid=True)
